# %%
import genesis.utils.mesh as mu  # adjust if your import path differs
# Out:
# [I 03/17/26 18:07:48.302 978004] [shell.py:_shell_pop_print@25] Graphical python shell detected, using wrapped sys.stdout
